# %%
import torch
import logging

# %%
s = {(1,2), (5,3), (10,11)}

# %%
logging.warning('warn')
# Out:
# WARNING:root:warn

# %%
for i, (x,y) in enumerate(s):
    print(i,x,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 for k, i, (x,y) in enumerate(s):
#       2     print(i,x,y)
#
# ValueError: not enough values to unpack (expected 3, got 2)
